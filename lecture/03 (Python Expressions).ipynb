# %%
from datascience import *
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')
import warnings
warnings.simplefilter(action="ignore", category=FutureWarning)

from urllib.request import urlopen 
import re
def read_url(url): 
    return re.sub('\\s+', ' ', urlopen(url).read().decode())

# %%
4 + 2
4 - 2
4*2
4/2
10/2
11/2
11//2 #Note integer addition.
2/4
1/3
4 ** 2
# Out:
# 1.0

# %%
1 + 2*3
# Out:
# 7

# %%
a = 10
b = 20
a + b
# Out:
# 30

# %%
a = 10
b = a + 10
a + b
# Out:
# 30

# %%
a = 10
b = a + 10
a = 20
b
# Out:
# 20

# %%
purchase_price = 5.00
state_tax_rate = 0.075
county_tax_rate = 0.02
city_tax_rate = 0.01
sales_tax_rate = state_tax_rate + county_tax_rate + city_tax_rate
purchase_price + sales_tax_rate*purchase_price
# Out:
# 5.525

# %%
initial = 2766000
final = 2814000
(final - initial)/initial # 1.7%
# Out:
# 0.01735357917570499

# %%
initial = 2766
final = 2814
(final - initial)/initial # 1.7%
# Out:
# 0.01735357917570499

# %%
# More functions
abs(-12)
round(5-1.2)
max(2,2+3,4)
# Out:
# 5

# %%
log(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 log(10)
#
# NameError: name 'log' is not defined

# %%
import math
math.log(10)
# Out:
# 2.302585092994046

# %%
sqrt(10)
math.sqrt(10)
# Out:
# 3.1622776601683795
