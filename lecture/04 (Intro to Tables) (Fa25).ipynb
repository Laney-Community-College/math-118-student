# %%
from datascience import *
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')
import warnings
warnings.simplefilter(action="ignore", category=FutureWarning)

from urllib.request import urlopen 
import re
def read_url(url): 
    return re.sub('\\s+', ' ', urlopen(url).read().decode())

# %%
cones = Table.read_table('cones.csv')

# %%
# cones

# %%
# cones.show(2) #Shows two lines
# cones.show() #Shows the whole table

# %%
# cones.select('Flavor')
# cones.select('Favor','Price')
# cones [Doesn't change table]
# cones.drop('Color')
# cones_without_color = cones.select('Flavor','Price')

# %%
# cones.where('Flavor','strawberry')
# cones.sort('Price')
# cones.sort('Price',descending=True)

# %%
nba = Table.read_table('nba_salaries.csv')
# nba
# nba.show()
# nba

# %%
# Challenge:
# Make table with just point guards
# Call the table point_gaurds in the 2020 season
# What point guard had the highest salary?
# What point guard had the lowest salary?
# point_guards_2020 = nba.where('position','PG').where('season',2020)
# point_guards_2020
# point_guards_2020.sort('salary')
# point_guards_2020.sort('salary',descending=True)
