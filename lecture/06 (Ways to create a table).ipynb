# %%
from datascience import *
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')
import warnings
warnings.simplefilter(action="ignore", category=FutureWarning)

from urllib.request import urlopen 
import re
def read_url(url): 
    return re.sub('\\s+', ' ', urlopen(url).read().decode())

# %% [markdown]
# # Ways to create a table
# ## 1. Read from file
# ## 2. Modify an existing table
# ## 3. Create from scratch

# %%
cones = Table.read_table('cones.csv')
# cones
# Out:
# Flavor     | Color       | Price
# strawberry | pink        | 3.55
# chocolate  | light brown | 4.75
# chocolate  | dark brown  | 5.25
# strawberry | pink        | 5.25
# chocolate  | dark brown  | 5.25
# bubblegum  | pink        | 4.75

# %%
cones_without_price = cones.drop('Price')

# %%
# Can add columns
cones.num_rows
ratings = make_array(1,4,4,2,3,2)
cones_with_ratings = cones.with_column('Rating',ratings)
# cones_with_ratings

# %% [markdown]
# # Table from scratch
# # Challenge: Produce this table
# Length &nbsp;	Age &nbsp; Rank
#
# 1.81	 &nbsp; &nbsp; &nbsp; &nbsp;1.0  &nbsp;&nbsp;&nbsp;&nbsp;  3
#
# 1.85 &nbsp; &nbsp;&nbsp;&nbsp;&nbsp;1.5  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;  4
#
# 1.87 &nbsp;&nbsp;&nbsp;&nbsp;	&nbsp;1.5 &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;   5
#
# 1.77 &nbsp;&nbsp;&nbsp;&nbsp;	&nbsp;1.5 &nbsp; &nbsp;&nbsp;&nbsp;  6

# %%
lengths = make_array(1.81,1.85,1.87,1.77)
ages = make_array(1.0,1.5,1.5,1.5)
ranks = np.arange(3,7)
my_table = Table().with_columns('Length',lengths, 'Age',ages, 'Rank',ranks)
